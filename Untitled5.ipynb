# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamking5216-creator/bootcamp_work/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
subjects = ["Python", "Math", "AI", "Data"]
c={
    "name":"shivam",
    "class":1,
    "city":"mathura",
    "grade":"A+",
    "name of collage":"GLA"
}
print(c['grade']=="A+")
# Out:
# {'name': 'shivam', 'class': 1, 'city': 'mathura', 'grade': 'A+', 'name of collage': 'GLA'}

# %%
marks = 72

if marks>80:
  print("Dinstiction")
elif(marks>=40 and marks<=70):
  print("pass")
else:
  print("Fail")
# Out:
# Pass

# %%
age=int(input(""))
if(age<13):
  print("child")
elif(age>=13 and age<=19):
  print("teenager")
else:
  print("adult")

# %%
l=[{"name":"thor","grade":"a"},{"name":"hulk","grade":"b"},{"name":"jhonny","grade":"c"}]
for i in l:
  if(i['grade']=='a'):
    print(i['name'])
  elif(i['grade']=='b'):
    print(i['name'])
  else:
    print(i['name'])
# Out:
# thor
# hulk
# jhonny
